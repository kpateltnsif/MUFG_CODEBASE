# %% [markdown]
# # 🔍 Linear Search Algorithm
#
# ---
#
# ##  Introduction
# Linear Search (also known as **Sequential Search**) is the most basic search algorithm that checks every element in the array one by one until it finds the target value or reaches the end of the list.
#
# ---
#
# ##  How it Works
# Suppose we have the array: `[10, 25, 30, 45, 50]`, and we are searching for `45`.
#
# 1. Compare `10` with `45` → Not a match
# 2. Compare `25` with `45` → Not a match
# 3. Compare `30` with `45` → Not a match
# 4. Compare `45` with `45` → ✅ Match found at index `3`
# 5. Stop searching
#
# ---
#
# ##  Algorithm Flow (Visualization)
#
# Start from index 0
# |
# V
# [10, 25, 30, 45, 50] <-- Target = 45
# ↑
# Match Found
#
#
#
# ---
#
# ##  Function Signature
# A Linear Search function usually takes:
# - An **array (list)** of elements
# - A **target value** to search for
#
# Returns:
# - The **index** of the target if found
# - `-1` if not found
#
# ---
#
# ## 🛠️ Use Cases
# - Searching in **unsorted arrays**
# - When the dataset is **small**
# - Situations with **memory constraints**
# - Simple or one-time search tasks
#
# ---
#
# ##  Time Complexity
#
# | Case        | Time       |
# |-------------|------------|
# | Best Case   | O(1)       |
# | Average Case| O(n)       |
# | Worst Case  | O(n)       |
#
# Best case occurs when the element is at the start.
# Worst case is when the element is at the end or not present.
#
# ---
#
# ##  Space Complexity
# - **O(1)**: Constant space — only variables for indexing and comparison
#
# ---
#
# ##  Pros and Cons
#
# ###  Pros:
# - Easy to implement
# - Works on **unsorted data**
# - No preprocessing required
#
# ###  Cons:
# - Not efficient for **large datasets**
# - Slower than **Binary Search** for sorted data
#
# ---
#
# ##  Real-life Examples:
# - Looking for a number in an unsorted phone contact list
# - Scanning through physical documents manually
# - Searching for a word in a non-indexed text file
#
# ---
